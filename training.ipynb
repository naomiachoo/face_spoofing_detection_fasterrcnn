# %% [markdown]
# <a href="https://colab.research.google.com/github/yayanberutu/face_spoofing_detection_fasterrcnn/blob/master/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import division
from __future__ import print_function
from __future__ import absolute_import
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle
import math
import cv2
import copy
from matplotlib import pyplot as plt
import tensorflow as tf
import pandas as pd
import os

from sklearn.metrics import average_precision_score

from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Flatten, Dense, Input, Conv2D, MaxPooling2D, Dropout
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, TimeDistributed
from keras.engine.topology import get_source_inputs
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.objectives import categorical_crossentropy

from keras.models import Model
from keras.utils import generic_utils
from keras.engine import Layer, InputSpec
from keras import initializers, regularizers

# %%
# !pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading https://files.pythonhosted.org/packages/85/cc/a27e73cf8b23f2ce4bdd2b7089a42a7819ce6dd7366dceba406ddc5daa9c/tensorflow_gpu-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl (394.3MB)
#      |████████████████████████████████| 394.3MB 40kB/s
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.19.5)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.7.4.3)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.4.0)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.36.2)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.32.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.10.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.4.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.3.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.12.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow-gpu) (54.1.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow-gpu) (1.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow-gpu) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow-gpu) (0.4.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow-gpu) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow-gpu) (2.23.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow-gpu) (3.7.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow-gpu) (3.4.1)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.4.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Preprocessing Image**

# %%
def resize(img, height, width):
    resize_img = cv2.resize(img, (width, height), interpolation=cv2.INTER_NEAREST)
    return resize_img

# %%
def denoise(img):
    denoise_img = cv2.fastNlMeansDenoisingColored(img, None, 10, 10, 7, 15)
    return denoise_img

# %% [markdown]
# Konfigurasi

# %%
class Config:
    def __init__(self):
        # print the process or not
        self.verbose = True
        # name of base network
        self.network = 'vgg'

        #config for data augmentation
        self.use_horizontal_flips = False
        self.use_vertical_flips = False
        self.rot_90 = False
        
        # anchor box scales
        # Note that if im_size is smaller, anchor_box_scales should be scaled
        # Original anchor_box_scales in the paper is [128, 256, 512]
        self.anchor_box_scales = [128, 256, 512]
        
        # Anchor box ratios
        self.anchor_box_ratios = [[1,1], [1./math.sqrt(2), 2./math.sqrt(2)], [2./math.sqrt(2), 1./math.sqrt(2)]]

        # size to resize the smallest side of the image
        # original setting in paper is 600. Set to 300 in here to save training time
        self.im_size = 300
        
        # image channel-wise mean to substract
        self.img_channel_mean = [103.939, 116.779, 123.68]

        self.img_scaling_factor = 1.0
        
        # number of ROIs at once
        self.num_rois = 4
        
        # stride at the RPN (it depends on the network configuration)
        self.rpn_stride  = 16

        self.balanced_classes = False

        # scaling the stdev
        self.std_scaling = 4.0

        self.classifier_regr_std = [8.0, 8.0, 4.0, 4.0]

        self.rpn_min_overlap = 0.3
        self.rpn_max_overlap = 0.7

        self.classifier_min_overlap = 0.1
        self.classifier_max_overlap = 0.5
    
        self.class_mapping = None

        self.model_path = None

# %% [markdown]
# **Ambil Data Gambar dari file txt**

# %%
def get_data(input_path):
    """Parse data dari file txt
    Parameter:
      input_path: path file txt
    Return:
      Semua data berupa list(path tiap gambar, width, height, list(bounding_box))

    """

    found_bg = False

    all_imgs = {}

    classes_count = {}

    class_mapping = {}

    visualise = True

    i = 1

    with open(input_path, 'r') as f:
        print('Parsing annotation files')

        for line in f:

            # print process
            sys.stdout.write('r' + 'idx=' + str(i))
            i += 1

            line_split = line.strip('\n').split(' ')

            filename, stat = line_split
            filename = '/content/drive/MyDrive/Semester 6/TA/DATASET/' + filename
            print(filename)
            if stat == 1 :
                  class_name = 'spoof'
            else:
                  class_name = 'live'

            try:
                  bbox_filename = filename.replace('.jpg', '_BB.txt')  
                  with open(bbox_filename, 'r') as f2:
                        for data in f2:
                              line_split2 = data.strip('\n').split(' ') 
            except FileNotFoundError:
                  print('file ' + filename +' tidak bisa ditemukan!')
                  continue
            else:
                  x1, y1, x2, y2 = line_split2[:4]
            
            # Format file txt: 
                # train_label.txt : (path, stat)
                # <nama_fle>_BB.txt: (x1, y1, x2, y2)
            # x1, y1, x2, y2 merupakan ukuran pixel dari gambar asli
            # (x1, y1) koordinat kiri atas
            # (x2, y2) koordinat kanan bawah

            if class_name not in classes_count:
                classes_count[class_name] = 1
            else:
                classes_count[class_name] += 1

            if class_name not in class_mapping:
                if class_name == 'bg' and found_bg == False:
                    print('Found class name with special name bg. Will be treated as a background region (this is usually for hard negative mining).')
                    found_bg = True
                class_mapping[class_name] = len(class_mapping)

            if filename not in all_imgs:
                all_imgs[filename] = {}

                img = cv2.imread(filename)
                rows,cols = img.shape[:2]
                all_imgs[filename]['filepath'] = filename
                all_imgs[filename]['width'] = cols
                all_imgs[filename]['height'] = rows
                all_imgs[filename]['bboxes'] = []

            all_imgs[filename]['bboxes'].append({'class': class_name, 'x1': int(x1), 'x2': int(x2), 'y1': int(y1), 'y2': int(y2)})

        all_data = []
        for key in all_imgs:
            all_data.append(all_imgs[key])

        # pastikan bg class di elemen terakhir pada list
        if found_bg:
            if class_mapping['bg'] != len(class_mapping) - 1:
                key_to_switch = [key for key in class_mapping.keys() if class_mapping[key] == len(class_mapping)-1][0]
                val_to_switch = class_mapping['bg']
                class_mapping['bg'] = len(class_mapping) - 1
                class_mapping[key_to_switch] = val_to_switch
        
        return all_data, classes_count, class_mapping

# %% [markdown]
# **Implementasi ROI Polling Convolutional Layer**

# %%
class RoiPollingConv(Layer):
    def __init__(self, pool_size, num_rois, **kwargs):



        self.dim_ordering = K.image_dim_ordering()
        self.pool_size = pool_size
        self.num_rois = num_rois

        super(RoiPoolingConv, self).__init__(**kwargs)

    def build(self, input_shape):
        self.nb_channels = input_shape[0][3]   

    def compute_output_shape(self, input_shape):
        return None, self.num_rois, self.pool_size, self.pool_size, self.nb_channels

    def call(self, x, mask=None):

        assert(len(x) == 2)

        # x[0] is image with shape (rows, cols, channels)
        img = x[0]

        # x[1] is roi with shape (num_rois,4) with ordering (x,y,w,h)
        rois = x[1]

        input_shape = K.shape(img)

        outputs = []

        for roi_idx in range(self.num_rois):

            x = rois[0, roi_idx, 0]
            y = rois[0, roi_idx, 1]
            w = rois[0, roi_idx, 2]
            h = rois[0, roi_idx, 3]

            x = K.cast(x, 'int32')
            y = K.cast(y, 'int32')
            w = K.cast(w, 'int32')
            h = K.cast(h, 'int32')

            # Resized roi of the image to pooling size (7x7)
            rs = tf.image.resize_images(img[:, y:y+h, x:x+w, :], (self.pool_size, self.pool_size))
            outputs.append(rs)
                

        final_output = K.concatenate(outputs, axis=0)

        # Reshape to (1, num_rois, pool_size, pool_size, nb_channels)
        # Might be (1, 4, 7, 7, 3)
        final_output = K.reshape(final_output, (1, self.num_rois, self.pool_size, self.pool_size, self.nb_channels))

        # permute_dimensions is similar to transpose
        final_output = K.permute_dimensions(final_output, (0, 1, 2, 3, 4))

        return final_output
    
    
    def get_config(self):
        config = {'pool_size': self.pool_size,
                  'num_rois': self.num_rois}
        base_config = super(RoiPoolingConv, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# **Implentasi CNN Arsitektur VGG-16**

# %%
def get_img_output_length(width, height):
    def get_output_length(input_length):
        return input_length//16

    return get_output_length(width), get_output_length(height)    

def nn_base(input_tensor=None, trainable=False):


    input_shape = (None, None, 3)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    bn_axis = 3

    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    # x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    return x

# %% [markdown]
# **Implementasi RPN Layer**

# %%
def rpn_layer(base_layers, num_anchors):
    """Create a rpn layer
        Step1: Pass through the feature map from base layer to a 3x3 512 channels convolutional layer
                Keep the padding 'same' to preserve the feature map's size
        Step2: Pass the step1 to two (1,1) convolutional layer to replace the fully connected layer
                classification layer: num_anchors (9 in here) channels for 0, 1 sigmoid activation output
                regression layer: num_anchors*4 (36 in here) channels for computing the regression of bboxes with linear activation
    Args:
        base_layers: vgg in here
        num_anchors: 9 in here

    Returns:
        [x_class, x_regr, base_layers]
        x_class: classification for whether it's an object
        x_regr: bboxes regression
        base_layers: vgg in here
    """
    x = Conv2D(512, (3, 3), padding='same', activation='relu', kernel_initializer='normal', name='rpn_conv1')(base_layers)

    x_class = Conv2D(num_anchors, (1, 1), activation='sigmoid', kernel_initializer='uniform', name='rpn_out_class')(x)
    x_regr = Conv2D(num_anchors * 4, (1, 1), activation='linear', kernel_initializer='zero', name='rpn_out_regress')(x)

    return [x_class, x_regr, base_layers]

# %% [markdown]
# **Classifier layer**

# %%
def classifier_layer(base_layers, input_rois, num_rois, nb_classes = 4):
    """Create a classifier layer
    
    Args:
        base_layers: vgg
        input_rois: `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
        num_rois: number of rois to be processed in one time (4 in here)

    Returns:
        list(out_class, out_regr)
        out_class: classifier layer output
        out_regr: regression layer output
    """

    input_shape = (num_rois,7,7,512)

    pooling_regions = 7

    # out_roi_pool.shape = (1, num_rois, channels, pool_size, pool_size)
    # num_rois (4) 7x7 roi pooling
    out_roi_pool = RoiPoolingConv(pooling_regions, num_rois)([base_layers, input_rois])

    # Flatten the convlutional layer and connected to 2 FC and 2 dropout
    out = TimeDistributed(Flatten(name='flatten'))(out_roi_pool)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc1'))(out)
    out = TimeDistributed(Dropout(0.5))(out)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc2'))(out)
    out = TimeDistributed(Dropout(0.5))(out)

    # There are two output layer
    # out_class: softmax acivation function for classify the class name of the object
    # out_regr: linear activation function for bboxes coordinates regression
    out_class = TimeDistributed(Dense(nb_classes, activation='softmax', kernel_initializer='zero'), name='dense_class_{}'.format(nb_classes))(out)
    # note: no regression target for bg class
    out_regr = TimeDistributed(Dense(4 * (nb_classes-1), activation='linear', kernel_initializer='zero'), name='dense_regress_{}'.format(nb_classes))(out)

    return [out_class, out_regr]

# %% [markdown]
# **Calculate IoU (Intersection of Union)**

# %%
def union(au, bu, area_intersection):
	area_a = (au[2] - au[0]) * (au[3] - au[1])
	area_b = (bu[2] - bu[0]) * (bu[3] - bu[1])
	area_union = area_a + area_b - area_intersection
	return area_union

# %%
def intersection(ai, bi):
	x = max(ai[0], bi[0])
	y = max(ai[1], bi[1])
	w = min(ai[2], bi[2]) - x
	h = min(ai[3], bi[3]) - y
	if w < 0 or h < 0:
		return 0
	return w*h

# %%
def iou(a, b):
	# a and b should be (x1,y1,x2,y2)

	if a[0] >= a[2] or a[1] >= a[3] or b[0] >= b[2] or b[1] >= b[3]:
		return 0.0

	area_i = intersection(a, b)
	area_u = union(a, b, area_i)

	return float(area_i) / float(area_u + 1e-6)

# %% [markdown]
# **Calculate the rpn for all anchors of all images**

# %%
def calc_rpn(C, img_data, width, height, resized_width, resized_height, img_length_calc_function):
	"""(Important part!) Calculate the rpn for all anchors 
		If feature map has shape 38x50=1900, there are 1900x9=17100 potential anchors
	
	Args:
		C: config
		img_data: augmented image data
		width: original image width (e.g. 600)
		height: original image height (e.g. 800)
		resized_width: resized image width according to C.im_size (e.g. 300)
		resized_height: resized image height according to C.im_size (e.g. 400)
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size

	Returns:
		y_rpn_cls: list(num_bboxes, y_is_box_valid + y_rpn_overlap)
			y_is_box_valid: 0 or 1 (0 means the box is invalid, 1 means the box is valid)
			y_rpn_overlap: 0 or 1 (0 means the box is not an object, 1 means the box is an object)
		y_rpn_regr: list(num_bboxes, 4*y_rpn_overlap + y_rpn_regr)
			y_rpn_regr: x1,y1,x2,y2 bunding boxes coordinates
	"""
	downscale = float(C.rpn_stride) 
	anchor_sizes = C.anchor_box_scales   # 128, 256, 512
	anchor_ratios = C.anchor_box_ratios  # 1:1, 1:2*sqrt(2), 2*sqrt(2):1
	num_anchors = len(anchor_sizes) * len(anchor_ratios) # 3x3=9

	# calculate the output map size based on the network architecture
	(output_width, output_height) = img_length_calc_function(resized_width, resized_height)

	n_anchratios = len(anchor_ratios)    # 3
	
	# initialise empty output objectives
	y_rpn_overlap = np.zeros((output_height, output_width, num_anchors))
	y_is_box_valid = np.zeros((output_height, output_width, num_anchors))
	y_rpn_regr = np.zeros((output_height, output_width, num_anchors * 4))

	num_bboxes = len(img_data['bboxes'])

	num_anchors_for_bbox = np.zeros(num_bboxes).astype(int)
	best_anchor_for_bbox = -1*np.ones((num_bboxes, 4)).astype(int)
	best_iou_for_bbox = np.zeros(num_bboxes).astype(np.float32)
	best_x_for_bbox = np.zeros((num_bboxes, 4)).astype(int)
	best_dx_for_bbox = np.zeros((num_bboxes, 4)).astype(np.float32)

	# get the GT box coordinates, and resize to account for image resizing
	gta = np.zeros((num_bboxes, 4))
	for bbox_num, bbox in enumerate(img_data['bboxes']):
		# get the GT box coordinates, and resize to account for image resizing
		gta[bbox_num, 0] = bbox['x1'] * (resized_width / float(width))
		gta[bbox_num, 1] = bbox['x2'] * (resized_width / float(width))
		gta[bbox_num, 2] = bbox['y1'] * (resized_height / float(height))
		gta[bbox_num, 3] = bbox['y2'] * (resized_height / float(height))
	
	# rpn ground truth

	for anchor_size_idx in range(len(anchor_sizes)):
		for anchor_ratio_idx in range(n_anchratios):
			anchor_x = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][0]
			anchor_y = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][1]	
			
			for ix in range(output_width):					
				# x-coordinates of the current anchor box	
				x1_anc = downscale * (ix + 0.5) - anchor_x / 2
				x2_anc = downscale * (ix + 0.5) + anchor_x / 2	
				
				# ignore boxes that go across image boundaries					
				if x1_anc < 0 or x2_anc > resized_width:
					continue
					
				for jy in range(output_height):

					# y-coordinates of the current anchor box
					y1_anc = downscale * (jy + 0.5) - anchor_y / 2
					y2_anc = downscale * (jy + 0.5) + anchor_y / 2

					# ignore boxes that go across image boundaries
					if y1_anc < 0 or y2_anc > resized_height:
						continue

					# bbox_type indicates whether an anchor should be a target
					# Initialize with 'negative'
					bbox_type = 'neg'

					# this is the best IOU for the (x,y) coord and the current anchor
					# note that this is different from the best IOU for a GT bbox
					best_iou_for_loc = 0.0

					for bbox_num in range(num_bboxes):
						
						# get IOU of the current GT box and the current anchor box
						curr_iou = iou([gta[bbox_num, 0], gta[bbox_num, 2], gta[bbox_num, 1], gta[bbox_num, 3]], [x1_anc, y1_anc, x2_anc, y2_anc])
						# calculate the regression targets if they will be needed
						if curr_iou > best_iou_for_bbox[bbox_num] or curr_iou > C.rpn_max_overlap:
							cx = (gta[bbox_num, 0] + gta[bbox_num, 1]) / 2.0
							cy = (gta[bbox_num, 2] + gta[bbox_num, 3]) / 2.0
							cxa = (x1_anc + x2_anc)/2.0
							cya = (y1_anc + y2_anc)/2.0

							# x,y are the center point of ground-truth bbox
							# xa,ya are the center point of anchor bbox (xa=downscale * (ix + 0.5); ya=downscale * (iy+0.5))
							# w,h are the width and height of ground-truth bbox
							# wa,ha are the width and height of anchor bboxe
							# tx = (x - xa) / wa
							# ty = (y - ya) / ha
							# tw = log(w / wa)
							# th = log(h / ha)
							tx = (cx - cxa) / (x2_anc - x1_anc)
							ty = (cy - cya) / (y2_anc - y1_anc)
							tw = np.log((gta[bbox_num, 1] - gta[bbox_num, 0]) / (x2_anc - x1_anc))
							th = np.log((gta[bbox_num, 3] - gta[bbox_num, 2]) / (y2_anc - y1_anc))
						
						if img_data['bboxes'][bbox_num]['class'] != 'bg':

							# all GT boxes should be mapped to an anchor box, so we keep track of which anchor box was best
							if curr_iou > best_iou_for_bbox[bbox_num]:
								best_anchor_for_bbox[bbox_num] = [jy, ix, anchor_ratio_idx, anchor_size_idx]
								best_iou_for_bbox[bbox_num] = curr_iou
								best_x_for_bbox[bbox_num,:] = [x1_anc, x2_anc, y1_anc, y2_anc]
								best_dx_for_bbox[bbox_num,:] = [tx, ty, tw, th]

							# we set the anchor to positive if the IOU is >0.7 (it does not matter if there was another better box, it just indicates overlap)
							if curr_iou > C.rpn_max_overlap:
								bbox_type = 'pos'
								num_anchors_for_bbox[bbox_num] += 1
								# we update the regression layer target if this IOU is the best for the current (x,y) and anchor position
								if curr_iou > best_iou_for_loc:
									best_iou_for_loc = curr_iou
									best_regr = (tx, ty, tw, th)

							# if the IOU is >0.3 and <0.7, it is ambiguous and no included in the objective
							if C.rpn_min_overlap < curr_iou < C.rpn_max_overlap:
								# gray zone between neg and pos
								if bbox_type != 'pos':
									bbox_type = 'neutral'

					# turn on or off outputs depending on IOUs
					if bbox_type == 'neg':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'neutral':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'pos':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						start = 4 * (anchor_ratio_idx + n_anchratios * anchor_size_idx)
						y_rpn_regr[jy, ix, start:start+4] = best_regr

	# we ensure that every bbox has at least one positive RPN region

	for idx in range(num_anchors_for_bbox.shape[0]):
		if num_anchors_for_bbox[idx] == 0:
			# no box with an IOU greater than zero ...
			if best_anchor_for_bbox[idx, 0] == -1:
				continue
			y_is_box_valid[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			y_rpn_overlap[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			start = 4 * (best_anchor_for_bbox[idx,2] + n_anchratios * best_anchor_for_bbox[idx,3])
			y_rpn_regr[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], start:start+4] = best_dx_for_bbox[idx, :]

	y_rpn_overlap = np.transpose(y_rpn_overlap, (2, 0, 1))
	y_rpn_overlap = np.expand_dims(y_rpn_overlap, axis=0)

	y_is_box_valid = np.transpose(y_is_box_valid, (2, 0, 1))
	y_is_box_valid = np.expand_dims(y_is_box_valid, axis=0)

	y_rpn_regr = np.transpose(y_rpn_regr, (2, 0, 1))
	y_rpn_regr = np.expand_dims(y_rpn_regr, axis=0)

	pos_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 1, y_is_box_valid[0, :, :, :] == 1))
	neg_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 0, y_is_box_valid[0, :, :, :] == 1))

	num_pos = len(pos_locs[0])

	# one issue is that the RPN has many more negative than positive regions, so we turn off some of the negative
	# regions. We also limit it to 256 regions.
	num_regions = 256

	if len(pos_locs[0]) > num_regions/2:
		val_locs = random.sample(range(len(pos_locs[0])), len(pos_locs[0]) - num_regions/2)
		y_is_box_valid[0, pos_locs[0][val_locs], pos_locs[1][val_locs], pos_locs[2][val_locs]] = 0
		num_pos = num_regions/2

	if len(neg_locs[0]) + num_pos > num_regions:
		val_locs = random.sample(range(len(neg_locs[0])), len(neg_locs[0]) - num_pos)
		y_is_box_valid[0, neg_locs[0][val_locs], neg_locs[1][val_locs], neg_locs[2][val_locs]] = 0

	y_rpn_cls = np.concatenate([y_is_box_valid, y_rpn_overlap], axis=1)
	y_rpn_regr = np.concatenate([np.repeat(y_rpn_overlap, 4, axis=1), y_rpn_regr], axis=1)

	return np.copy(y_rpn_cls), np.copy(y_rpn_regr), num_pos

# %% [markdown]
# **Get new image size and augment the image**

# %%
def get_new_img_size(width, height, img_min_side=300):
      if width <= height:
            f = float(img_min_side) / width
            resized_height = int(f * height)
            resized_width = img_min_side
      else:
            f = float(img_min_side) / height
            resized_width = int(f * width)
            resized_height = img_min_side
      return resized_width, resized_height

# %%
def augment(img_data, config, augment=True):
	assert 'filepath' in img_data
	assert 'bboxes' in img_data
	assert 'width' in img_data
	assert 'height' in img_data

	img_data_aug = copy.deepcopy(img_data)

	img = cv2.imread(img_data_aug['filepath'])

	if augment:
		rows, cols = img.shape[:2]

		if config.use_horizontal_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 1)
			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				bbox['x2'] = cols - x1
				bbox['x1'] = cols - x2

		if config.use_vertical_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 0)
			for bbox in img_data_aug['bboxes']:
				y1 = bbox['y1']
				y2 = bbox['y2']
				bbox['y2'] = rows - y1
				bbox['y1'] = rows - y2

		if config.rot_90:
			angle = np.random.choice([0,90,180,270],1)[0]
			if angle == 270:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 0)
			elif angle == 180:
				img = cv2.flip(img, -1)
			elif angle == 90:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 1)
			elif angle == 0:
				pass

			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				y1 = bbox['y1']
				y2 = bbox['y2']
				if angle == 270:
					bbox['x1'] = y1
					bbox['x2'] = y2
					bbox['y1'] = cols - x2
					bbox['y2'] = cols - x1
				elif angle == 180:
					bbox['x2'] = cols - x1
					bbox['x1'] = cols - x2
					bbox['y2'] = rows - y1
					bbox['y1'] = rows - y2
				elif angle == 90:
					bbox['x1'] = rows - y2
					bbox['x2'] = rows - y1
					bbox['y1'] = x1
					bbox['y2'] = x2        
				elif angle == 0:
					pass

	img_data_aug['width'] = img.shape[1]
	img_data_aug['height'] = img.shape[0]
	return img_data_aug, img

# %% [markdown]
# **Generate ground_truth anchor**

# %%
def get_anchor_gt(all_img_data, C, img_length_calc_function, mode='train'):
	""" Yield the ground-truth anchors as Y (labels)
		
	Args:
		all_img_data: list(filepath, width, height, list(bboxes))
		C: config
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size
		mode: 'train' or 'test'; 'train' mode need augmentation

	Returns:
		x_img: image data after resized and scaling (smallest size = 300px)
		Y: [y_rpn_cls, y_rpn_regr]
		img_data_aug: augmented image data (original image with augmentation)
		debug_img: show image for debug
		num_pos: show number of positive anchors for debug
	"""
	while True:

		for img_data in all_img_data:
			try:

				# read in image, and optionally add augmentation

				if mode == 'train':
					img_data_aug, x_img = augment(img_data, C, augment=True)
				else:
					img_data_aug, x_img = augment(img_data, C, augment=False)

				(width, height) = (img_data_aug['width'], img_data_aug['height'])
				(rows, cols, _) = x_img.shape

				assert cols == width
				assert rows == height

				# get image dimensions for resizing
				(resized_width, resized_height) = get_new_img_size(width, height, C.im_size)

				# resize the image so that smalles side is length = 300px
				x_img = cv2.resize(x_img, (resized_width, resized_height), interpolation=cv2.INTER_CUBIC)
				debug_img = x_img.copy()

				try:
					y_rpn_cls, y_rpn_regr, num_pos = calc_rpn(C, img_data_aug, width, height, resized_width, resized_height, img_length_calc_function)
				except:
					continue

				# Zero-center by mean pixel, and preprocess image

				x_img = x_img[:,:, (2, 1, 0)]  # BGR -> RGB
				x_img = x_img.astype(np.float32)
				x_img[:, :, 0] -= C.img_channel_mean[0]
				x_img[:, :, 1] -= C.img_channel_mean[1]
				x_img[:, :, 2] -= C.img_channel_mean[2]
				x_img /= C.img_scaling_factor

				x_img = np.transpose(x_img, (2, 0, 1))
				x_img = np.expand_dims(x_img, axis=0)

				y_rpn_regr[:, y_rpn_regr.shape[1]//2:, :, :] *= C.std_scaling

				x_img = np.transpose(x_img, (0, 2, 3, 1))
				y_rpn_cls = np.transpose(y_rpn_cls, (0, 2, 3, 1))
				y_rpn_regr = np.transpose(y_rpn_regr, (0, 2, 3, 1))

				yield np.copy(x_img), [np.copy(y_rpn_cls), np.copy(y_rpn_regr)], img_data_aug, debug_img, num_pos

			except Exception as e:
				print(e)
				continue

# %% [markdown]
# **Define loss functions for all four outputs**

# %%
lambda_rpn_regr = 1.0
lambda_rpn_class = 1.0

lambda_cls_regr = 1.0
lambda_cls_class = 1.0

epsilon = 1e-4

# %%
def rpn_loss_regr(num_anchors):
    """Loss function for rpn regression
    Args:
        num_anchors: number of anchors (9 in here)
    Returns:
        Smooth L1 loss function 
                           0.5*x*x (if x_abs < 1)
                           x_abx - 0.5 (otherwise)
    """
    def rpn_loss_regr_fixed_num(y_true, y_pred):

        # x is the difference between true value and predicted vaue
        x = y_true[:, :, :, 4 * num_anchors:] - y_pred

        # absolute value of x
        x_abs = K.abs(x)

        # If x_abs <= 1.0, x_bool = 1
        x_bool = K.cast(K.less_equal(x_abs, 1.0), tf.float32)

        return lambda_rpn_regr * K.sum(
            y_true[:, :, :, :4 * num_anchors] * (x_bool * (0.5 * x * x) + (1 - x_bool) * (x_abs - 0.5))) / K.sum(epsilon + y_true[:, :, :, :4 * num_anchors])

    return rpn_loss_regr_fixed_num

# %%
def rpn_loss_cls(num_anchors):
    """Loss function for rpn classification
    Args:
        num_anchors: number of anchors (9 in here)
        y_true[:, :, :, :9]: [0,1,0,0,0,0,0,1,0] means only the second and the eighth box is valid which contains pos or neg anchor => isValid
        y_true[:, :, :, 9:]: [0,1,0,0,0,0,0,0,0] means the second box is pos and eighth box is negative
    Returns:
        lambda * sum((binary_crossentropy(isValid*y_pred,y_true))) / N
    """
    def rpn_loss_cls_fixed_num(y_true, y_pred):

            return lambda_rpn_class * K.sum(y_true[:, :, :, :num_anchors] * K.binary_crossentropy(y_pred[:, :, :, :], y_true[:, :, :, num_anchors:])) / K.sum(epsilon + y_true[:, :, :, :num_anchors])

    return rpn_loss_cls_fixed_num

# %%
def class_loss_regr(num_classes):
    """Loss function for rpn regression
    Args:
        num_anchors: number of anchors (9 in here)
    Returns:
        Smooth L1 loss function 
                           0.5*x*x (if x_abs < 1)
                           x_abx - 0.5 (otherwise)
    """
    def class_loss_regr_fixed_num(y_true, y_pred):
        x = y_true[:, :, 4*num_classes:] - y_pred
        x_abs = K.abs(x)
        x_bool = K.cast(K.less_equal(x_abs, 1.0), 'float32')
        return lambda_cls_regr * K.sum(y_true[:, :, :4*num_classes] * (x_bool * (0.5 * x * x) + (1 - x_bool) * (x_abs - 0.5))) / K.sum(epsilon + y_true[:, :, :4*num_classes])
    return class_loss_regr_fixed_num

# %%
def class_loss_cls(y_true, y_pred):
    return lambda_cls_class * K.mean(categorical_crossentropy(y_true[0, :, :], y_pred[0, :, :]))

# %%
def non_max_suppression_fast(boxes, probs, overlap_thresh=0.9, max_boxes=300):
    # code used from here: http://www.pyimagesearch.com/2015/02/16/faster-non-maximum-suppression-python/
    # if there are no boxes, return an empty list

    # Process explanation:
    #   Step 1: Sort the probs list
    #   Step 2: Find the larget prob 'Last' in the list and save it to the pick list
    #   Step 3: Calculate the IoU with 'Last' box and other boxes in the list. If the IoU is larger than overlap_threshold, delete the box from list
    #   Step 4: Repeat step 2 and step 3 until there is no item in the probs list 
    if len(boxes) == 0:
        return []

    # grab the coordinates of the bounding boxes
    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2]
    y2 = boxes[:, 3]

    np.testing.assert_array_less(x1, x2)
    np.testing.assert_array_less(y1, y2)

    # if the bounding boxes integers, convert them to floats --
    # this is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")

    # initialize the list of picked indexes	
    pick = []

    # calculate the areas
    area = (x2 - x1) * (y2 - y1)

    # sort the bounding boxes 
    idxs = np.argsort(probs)

    # keep looping while some indexes still remain in the indexes
    # list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the
        # index value to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)

        # find the intersection

        xx1_int = np.maximum(x1[i], x1[idxs[:last]])
        yy1_int = np.maximum(y1[i], y1[idxs[:last]])
        xx2_int = np.minimum(x2[i], x2[idxs[:last]])
        yy2_int = np.minimum(y2[i], y2[idxs[:last]])

        ww_int = np.maximum(0, xx2_int - xx1_int)
        hh_int = np.maximum(0, yy2_int - yy1_int)

        area_int = ww_int * hh_int

        # find the union
        area_union = area[i] + area[idxs[:last]] - area_int

        # compute the ratio of overlap
        overlap = area_int/(area_union + 1e-6)

        # delete all indexes from the index list that have
        idxs = np.delete(idxs, np.concatenate(([last],
            np.where(overlap > overlap_thresh)[0])))

        if len(pick) >= max_boxes:
            break

    # return only the bounding boxes that were picked using the integer data type
    boxes = boxes[pick].astype("int")
    probs = probs[pick]
    return boxes, probs

# %%
def apply_regr_np(X, T):
    """Apply regression layer to all anchors in one feature map

    Args:
        X: shape=(4, 18, 25) the current anchor type for all points in the feature map
        T: regression layer shape=(4, 18, 25)

    Returns:
        X: regressed position and size for current anchor
    """
    try:
        x = X[0, :, :]
        y = X[1, :, :]
        w = X[2, :, :]
        h = X[3, :, :]

        tx = T[0, :, :]
        ty = T[1, :, :]
        tw = T[2, :, :]
        th = T[3, :, :]

        cx = x + w/2.
        cy = y + h/2.
        cx1 = tx * w + cx
        cy1 = ty * h + cy

        w1 = np.exp(tw.astype(np.float64)) * w
        h1 = np.exp(th.astype(np.float64)) * h
        x1 = cx1 - w1/2.
        y1 = cy1 - h1/2.

        x1 = np.round(x1)
        y1 = np.round(y1)
        w1 = np.round(w1)
        h1 = np.round(h1)
        return np.stack([x1, y1, w1, h1])
    except Exception as e:
        print(e)
        return X

# %%
def apply_regr(x, y, w, h, tx, ty, tw, th):
    # Apply regression to x, y, w and h
    try:
        cx = x + w/2.
        cy = y + h/2.
        cx1 = tx * w + cx
        cy1 = ty * h + cy
        w1 = math.exp(tw) * w
        h1 = math.exp(th) * h
        x1 = cx1 - w1/2.
        y1 = cy1 - h1/2.
        x1 = int(round(x1))
        y1 = int(round(y1))
        w1 = int(round(w1))
        h1 = int(round(h1))

        return x1, y1, w1, h1

    except ValueError:
        return x, y, w, h
    except OverflowError:
        return x, y, w, h
    except Exception as e:
        print(e)
        return x, y, w, h

# %%
def calc_iou(R, img_data, C, class_mapping):
    """Converts from (x1,y1,x2,y2) to (x,y,w,h) format

    Args:
        R: bboxes, probs
    """
    bboxes = img_data['bboxes']
    (width, height) = (img_data['width'], img_data['height'])
    # get image dimensions for resizing
    (resized_width, resized_height) = get_new_img_size(width, height, C.im_size)

    gta = np.zeros((len(bboxes), 4))

    for bbox_num, bbox in enumerate(bboxes):
        # get the GT box coordinates, and resize to account for image resizing
        # gta[bbox_num, 0] = (40 * (600 / 800)) / 16 = int(round(1.875)) = 2 (x in feature map)
        gta[bbox_num, 0] = int(round(bbox['x1'] * (resized_width / float(width))/C.rpn_stride))
        gta[bbox_num, 1] = int(round(bbox['x2'] * (resized_width / float(width))/C.rpn_stride))
        gta[bbox_num, 2] = int(round(bbox['y1'] * (resized_height / float(height))/C.rpn_stride))
        gta[bbox_num, 3] = int(round(bbox['y2'] * (resized_height / float(height))/C.rpn_stride))

    x_roi = []
    y_class_num = []
    y_class_regr_coords = []
    y_class_regr_label = []
    IoUs = [] # for debugging only

    # R.shape[0]: number of bboxes (=300 from non_max_suppression)
    for ix in range(R.shape[0]):
        (x1, y1, x2, y2) = R[ix, :]
        x1 = int(round(x1))
        y1 = int(round(y1))
        x2 = int(round(x2))
        y2 = int(round(y2))

        best_iou = 0.0
        best_bbox = -1
        # Iterate through all the ground-truth bboxes to calculate the iou
        for bbox_num in range(len(bboxes)):
            curr_iou = iou([gta[bbox_num, 0], gta[bbox_num, 2], gta[bbox_num, 1], gta[bbox_num, 3]], [x1, y1, x2, y2])

            # Find out the corresponding ground-truth bbox_num with larget iou
            if curr_iou > best_iou:
                best_iou = curr_iou
                best_bbox = bbox_num

        if best_iou < C.classifier_min_overlap:
                continue
        else:
            w = x2 - x1
            h = y2 - y1
            x_roi.append([x1, y1, w, h])
            IoUs.append(best_iou)

            if C.classifier_min_overlap <= best_iou < C.classifier_max_overlap:
                # hard negative example
                cls_name = 'bg'
            elif C.classifier_max_overlap <= best_iou:
                cls_name = bboxes[best_bbox]['class']
                cxg = (gta[best_bbox, 0] + gta[best_bbox, 1]) / 2.0
                cyg = (gta[best_bbox, 2] + gta[best_bbox, 3]) / 2.0

                cx = x1 + w / 2.0
                cy = y1 + h / 2.0

                tx = (cxg - cx) / float(w)
                ty = (cyg - cy) / float(h)
                tw = np.log((gta[best_bbox, 1] - gta[best_bbox, 0]) / float(w))
                th = np.log((gta[best_bbox, 3] - gta[best_bbox, 2]) / float(h))
            else:
                print('roi = {}'.format(best_iou))
                raise RuntimeError

        class_num = class_mapping[cls_name]
        class_label = len(class_mapping) * [0]
        class_label[class_num] = 1
        y_class_num.append(copy.deepcopy(class_label))
        coords = [0] * 4 * (len(class_mapping) - 1)
        labels = [0] * 4 * (len(class_mapping) - 1)
        if cls_name != 'bg':
            label_pos = 4 * class_num
            sx, sy, sw, sh = C.classifier_regr_std
            coords[label_pos:4+label_pos] = [sx*tx, sy*ty, sw*tw, sh*th]
            labels[label_pos:4+label_pos] = [1, 1, 1, 1]
            y_class_regr_coords.append(copy.deepcopy(coords))
            y_class_regr_label.append(copy.deepcopy(labels))
        else:
            y_class_regr_coords.append(copy.deepcopy(coords))
            y_class_regr_label.append(copy.deepcopy(labels))

    if len(x_roi) == 0:
        return None, None, None, None

    # bboxes that iou > C.classifier_min_overlap for all gt bboxes in 300 non_max_suppression bboxes
    X = np.array(x_roi)
    # one hot code for bboxes from above => x_roi (X)
    Y1 = np.array(y_class_num)
    # corresponding labels and corresponding gt bboxes
    Y2 = np.concatenate([np.array(y_class_regr_label),np.array(y_class_regr_coords)],axis=1)

    return np.expand_dims(X, axis=0), np.expand_dims(Y1, axis=0), np.expand_dims(Y2, axis=0), IoUs

# %%
def rpn_to_roi(rpn_layer, regr_layer, C, dim_ordering, use_regr=True, max_boxes=300,overlap_thresh=0.9):
	"""Convert rpn layer to roi bboxes

	Args: (num_anchors = 9)
		rpn_layer: output layer for rpn classification 
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 18) if resized image is 400 width and 300
		regr_layer: output layer for rpn regression
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 72) if resized image is 400 width and 300
		C: config
		use_regr: Wether to use bboxes regression in rpn
		max_boxes: max bboxes number for non-max-suppression (NMS)
		overlap_thresh: If iou in NMS is larger than this threshold, drop the box

	Returns:
		result: boxes from non-max-suppression (shape=(300, 4))
			boxes: coordinates for bboxes (on the feature map)
	"""
	regr_layer = regr_layer / C.std_scaling

	anchor_sizes = C.anchor_box_scales   # (3 in here)
	anchor_ratios = C.anchor_box_ratios  # (3 in here)

	assert rpn_layer.shape[0] == 1

	(rows, cols) = rpn_layer.shape[1:3]

	curr_layer = 0

	# A.shape = (4, feature_map.height, feature_map.width, num_anchors) 
	# Might be (4, 18, 25, 18) if resized image is 400 width and 300
	# A is the coordinates for 9 anchors for every point in the feature map 
	# => all 18x25x9=4050 anchors cooridnates
	A = np.zeros((4, rpn_layer.shape[1], rpn_layer.shape[2], rpn_layer.shape[3]))

	for anchor_size in anchor_sizes:
		for anchor_ratio in anchor_ratios:
			# anchor_x = (128 * 1) / 16 = 8  => width of current anchor
			# anchor_y = (128 * 2) / 16 = 16 => height of current anchor
			anchor_x = (anchor_size * anchor_ratio[0])/C.rpn_stride
			anchor_y = (anchor_size * anchor_ratio[1])/C.rpn_stride
			
			# curr_layer: 0~8 (9 anchors)
			# the Kth anchor of all position in the feature map (9th in total)
			regr = regr_layer[0, :, :, 4 * curr_layer:4 * curr_layer + 4] # shape => (18, 25, 4)
			regr = np.transpose(regr, (2, 0, 1)) # shape => (4, 18, 25)

			# Create 18x25 mesh grid
			# For every point in x, there are all the y points and vice versa
			# X.shape = (18, 25)
			# Y.shape = (18, 25)
			X, Y = np.meshgrid(np.arange(cols),np. arange(rows))

			# Calculate anchor position and size for each feature map point
			A[0, :, :, curr_layer] = X - anchor_x/2 # Top left x coordinate
			A[1, :, :, curr_layer] = Y - anchor_y/2 # Top left y coordinate
			A[2, :, :, curr_layer] = anchor_x       # width of current anchor
			A[3, :, :, curr_layer] = anchor_y       # height of current anchor

			# Apply regression to x, y, w and h if there is rpn regression layer
			if use_regr:
				A[:, :, :, curr_layer] = apply_regr_np(A[:, :, :, curr_layer], regr)

			# Avoid width and height exceeding 1
			A[2, :, :, curr_layer] = np.maximum(1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.maximum(1, A[3, :, :, curr_layer])

			# Convert (x, y , w, h) to (x1, y1, x2, y2)
			# x1, y1 is top left coordinate
			# x2, y2 is bottom right coordinate
			A[2, :, :, curr_layer] += A[0, :, :, curr_layer]
			A[3, :, :, curr_layer] += A[1, :, :, curr_layer]

			# Avoid bboxes drawn outside the feature map
			A[0, :, :, curr_layer] = np.maximum(0, A[0, :, :, curr_layer])
			A[1, :, :, curr_layer] = np.maximum(0, A[1, :, :, curr_layer])
			A[2, :, :, curr_layer] = np.minimum(cols-1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.minimum(rows-1, A[3, :, :, curr_layer])

			curr_layer += 1

	all_boxes = np.reshape(A.transpose((0, 3, 1, 2)), (4, -1)).transpose((1, 0))  # shape=(4050, 4)
	all_probs = rpn_layer.transpose((0, 3, 1, 2)).reshape((-1))                   # shape=(4050,)

	x1 = all_boxes[:, 0]
	y1 = all_boxes[:, 1]
	x2 = all_boxes[:, 2]
	y2 = all_boxes[:, 3]

	# Find out the bboxes which is illegal and delete them from bboxes list
	idxs = np.where((x1 - x2 >= 0) | (y1 - y2 >= 0))

	all_boxes = np.delete(all_boxes, idxs, 0)
	all_probs = np.delete(all_probs, idxs, 0)

	# Apply non_max_suppression
	# Only extract the bboxes. Don't need rpn probs in the later process
	result = non_max_suppression_fast(all_boxes, all_probs, overlap_thresh=overlap_thresh, max_boxes=max_boxes)[0]

	return result

# %% [markdown]
# **Training Process**

# %%
def preparation():
  base_path = '/content/drive/MyDrive/Semester 6/TA/DATASET'
  
  # Lokasi anotasi file untuk training
  train_path =  '/content/drive/MyDrive/Semester 6/TA/DATASET/metas/intra_test/train_label.txt' 
  
  num_rois = 4 # Number of RoIs to process at once.
  
  # Augmentation flag
  horizontal_flips = True # Augment with horizontal flips in training. 
  vertical_flips = True   # Augment with vertical flips in training. 
  rot_90 = True           # Augment with 90 degree rotations in training. 
  

  output_weight_path = os.path.join(base_path, '/Model/model_frcnn_vgg.hdf5')
  
  record_path = os.path.join(base_path, '/Model/record.csv') # Record data (used to save the losses, classification accuracy and mean average precision)
  
  base_weight_path = os.path.join(base_path, '/Model/vgg16_weights_tf_dim_ordering_tf_kernels.h5')
  
  # menyimpan konfigurasi
  config_output_filename = os.path.join(base_path, '/Model/model_vgg_config.pickle')

    #--------------------------------------------------------#
    # This step will create a configuration                  #
    #--------------------------------------------------------#
  C = Config()
  C.use_horizontal_flips = horizontal_flips
  C.use_vertical_flips = vertical_flips
  C.rot_90 = rot_90
  
  C.record_path = record_path
  C.model_path = output_weight_path
  C.num_rois = num_rois

  C.base_net_weights = base_weight_path

  #ambil waktu sebelum get data
  st = time.time()
  
  #--------------------------------------------------------#
  # code dibawah ini digunakan untuk mengambil semua data  #
  #--------------------------------------------------------#

  train_imgs, classes_count, class_mapping = get_data(train_path)
  print()
  print('Spend %0.2f mins to load the data' % ((time.time()-st)/60) )

  if 'bg' not in classes_count:
    classes_count['bg'] = 0
    class_mapping['bg'] = len(class_mapping)
    
  # Contoh:
  #    classes_count: {'spoof': 100, 'live': 502, 'bg': 0}
  #    class_mapping: {'live': 0, 'spoof': 1, 'bg': 3}

  C.class_mapping = class_mapping
  print('Training images per class:')
  pprint.pprint(classes_count)
  print('Num classes (including bg) = {}'.format(len(classes_count)))
  print(class_mapping)

  # Save the configuration
  with open(config_output_filename, 'wb') as config_f:
	  pickle.dump(C,config_f)
	  print('Config has been written to {}, and can be loaded when testing to ensure correct results'.format(config_output_filename))
  
  # Shuffle the images with seed
  random.seed(1)
  random.shuffle(train_imgs)

  print('Num train samples (images) {}'.format(len(train_imgs)))

  # Get train data generator which generate X, Y, image_data
  data_gen_train = get_anchor_gt(train_imgs, C, get_img_output_length, mode='train')

# %% [markdown]
# **EXPLORE DATA GEN TRAIN**

# %%
def explore_data_gen_train():
  X, Y, image_data, debug_img, debug_num_pos = next(data_gen_train)
  print('Resized image:  height=%d width=%d C.im_size=%d'%(X.shape[1], X.shape[2], C.im_size))
  print('Feature map size: height=%d width=%d C.rpn_stride=%d'%(Y[0].shape[1], Y[0].shape[2], C.rpn_stride))
  print(X.shape)
  print(str(len(Y))+" includes 'y_rpn_cls' and 'y_rpn_regr'")
  print('Shape of y_rpn_cls {}'.format(Y[0].shape))
  print('Shape of y_rpn_regr {}'.format(Y[1].shape))
  print(image_data)

  print('Number of positive anchors for this image: %d' % (debug_num_pos))
  if debug_num_pos==0:
      gt_x1, gt_x2 = image_data['bboxes'][0]['x1']*(X.shape[2]/image_data['height']), image_data['bboxes'][0]['x2']*(X.shape[2]/image_data['height'])
      gt_y1, gt_y2 = image_data['bboxes'][0]['y1']*(X.shape[1]/image_data['width']), image_data['bboxes'][0]['y2']*(X.shape[1]/image_data['width'])
      gt_x1, gt_y1, gt_x2, gt_y2 = int(gt_x1), int(gt_y1), int(gt_x2), int(gt_y2)

      img = debug_img.copy()
      img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
      color = (0, 255, 0)
      cv2.putText(img, 'gt bbox', (gt_x1, gt_y1-5), cv2.FONT_HERSHEY_DUPLEX, 0.7, color, 1)
      cv2.rectangle(img, (gt_x1, gt_y1), (gt_x2, gt_y2), color, 2)
      cv2.circle(img, (int((gt_x1+gt_x2)/2), int((gt_y1+gt_y2)/2)), 3, color, -1)

      plt.grid()
      plt.imshow(img)
      plt.show()
  else:
      cls = Y[0][0]
      pos_cls = np.where(cls==1)
      print(pos_cls)
      regr = Y[1][0]
      pos_regr = np.where(regr==1)
      print(pos_regr)
      print('y_rpn_cls for possible pos anchor: {}'.format(cls[pos_cls[0][0],pos_cls[1][0],:]))
      print('y_rpn_regr for positive anchor: {}'.format(regr[pos_regr[0][0],pos_regr[1][0],:]))

      gt_x1, gt_x2 = image_data['bboxes'][0]['x1']*(X.shape[2]/image_data['width']), image_data['bboxes'][0]['x2']*(X.shape[2]/image_data['width'])
      gt_y1, gt_y2 = image_data['bboxes'][0]['y1']*(X.shape[1]/image_data['height']), image_data['bboxes'][0]['y2']*(X.shape[1]/image_data['height'])
      gt_x1, gt_y1, gt_x2, gt_y2 = int(gt_x1), int(gt_y1), int(gt_x2), int(gt_y2)

      img = debug_img.copy()
      img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
      color = (0, 255, 0)
      #   cv2.putText(img, 'gt bbox', (gt_x1, gt_y1-5), cv2.FONT_HERSHEY_DUPLEX, 0.7, color, 1)
      cv2.rectangle(img, (gt_x1, gt_y1), (gt_x2, gt_y2), color, 2)
      cv2.circle(img, (int((gt_x1+gt_x2)/2), int((gt_y1+gt_y2)/2)), 3, color, -1)

      # Add text
      textLabel = 'gt bbox'
      (retval,baseLine) = cv2.getTextSize(textLabel,cv2.FONT_HERSHEY_COMPLEX,0.5,1)
      textOrg = (gt_x1, gt_y1+5)
      cv2.rectangle(img, (textOrg[0] - 5, textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (0, 0, 0), 2)
      cv2.rectangle(img, (textOrg[0] - 5,textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (255, 255, 255), -1)
      cv2.putText(img, textLabel, textOrg, cv2.FONT_HERSHEY_DUPLEX, 0.5, (0, 0, 0), 1)

      # Draw positive anchors according to the y_rpn_regr
      for i in range(debug_num_pos):

          color = (100+i*(155/4), 0, 100+i*(155/4))

          idx = pos_regr[2][i*4]/4
          anchor_size = C.anchor_box_scales[int(idx/3)]
          anchor_ratio = C.anchor_box_ratios[2-int((idx+1)%3)]

          center = (pos_regr[1][i*4]*C.rpn_stride, pos_regr[0][i*4]*C.rpn_stride)
          print('Center position of positive anchor: ', center)
          cv2.circle(img, center, 3, color, -1)
          anc_w, anc_h = anchor_size*anchor_ratio[0], anchor_size*anchor_ratio[1]
          cv2.rectangle(img, (center[0]-int(anc_w/2), center[1]-int(anc_h/2)), (center[0]+int(anc_w/2), center[1]+int(anc_h/2)), color, 2)
          #cv2.putText(img, 'pos anchor bbox '+str(i+1), (center[0]-int(anc_w/2), center[1]-int(anc_h/2)-5), cv2.FONT_HERSHEY_DUPLEX, 0.5, color, 1)

  print('Green bboxes is ground-truth bbox. Others are positive anchors')
  plt.figure(figsize=(8,8))
  plt.grid()
  plt.imshow(img)
  plt.show()

# %% [markdown]
# **Build Model**

# %%
def build_model():
  input_shape_img = (None, None, 3)

  img_input = Input(shape=input_shape_img)
  roi_input = Input(shape=(None, 4))

  # define the base network (VGG here, can be Resnet50, Inception, etc)
  shared_layers = nn_base(img_input, trainable=True)
  # define the RPN, built on the base layers
  num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios) # 9
  rpn = rpn_layer(shared_layers, num_anchors)

  classifier = classifier_layer(shared_layers, roi_input, C.num_rois, nb_classes=len(classes_count))

  model_rpn = Model(img_input, rpn[:2])
  model_classifier = Model([img_input, roi_input], classifier)

  # this is a model that holds both the RPN and the classifier, used to load/save weights for the models
  model_all = Model([img_input, roi_input], rpn[:2] + classifier)

  # Because the google colab can only run the session several hours one time (then you need to connect again), 
  # we need to save the model and load the model to continue training
  if not os.path.isfile(C.model_path):
      #If this is the begin of the training, load the pre-traind base network such as vgg-16
      try:
          print('This is the first time training')
          print('loading weights from {}'.format(C.base_net_weights))
          model_rpn.load_weights(C.base_net_weights, by_name=True)
          model_classifier.load_weights(C.base_net_weights, by_name=True)
      except:
          print('Could not load pretrained model weights.')
      
      # Create the record.csv file to record losses, acc and mAP
      record_df = pd.DataFrame(columns=['mean_overlapping_bboxes', 'class_acc', 'loss_rpn_cls', 'loss_rpn_regr', 'loss_class_cls', 'loss_class_regr', 'curr_loss', 'elapsed_time', 'mAP'])
  else:
      # If this is a continued training, load the trained model from before
      print('Continue training based on previous trained model')
      print('Loading weights from {}'.format(C.model_path))
      model_rpn.load_weights(C.model_path, by_name=True)
      model_classifier.load_weights(C.model_path, by_name=True)
      
      # Load the records
      record_df = pd.read_csv(record_path)

      r_mean_overlapping_bboxes = record_df['mean_overlapping_bboxes']
      r_class_acc = record_df['class_acc']
      r_loss_rpn_cls = record_df['loss_rpn_cls']
      r_loss_rpn_regr = record_df['loss_rpn_regr']
      r_loss_class_cls = record_df['loss_class_cls']
      r_loss_class_regr = record_df['loss_class_regr']
      r_curr_loss = record_df['curr_loss']
      r_elapsed_time = record_df['elapsed_time']
      r_mAP = record_df['mAP']

      print('Already train %dK batches'% (len(record_df)))

        
  optimizer = Adam(lr=1e-5)
  optimizer_classifier = Adam(lr=1e-5)
  model_rpn.compile(optimizer=optimizer, loss=[rpn_loss_cls(num_anchors), rpn_loss_regr(num_anchors)])
  model_classifier.compile(optimizer=optimizer_classifier, loss=[class_loss_cls, class_loss_regr(len(classes_count)-1)], metrics={'dense_class_{}'.format(len(classes_count)): 'accuracy'})
  model_all.compile(optimizer='sgd', loss='mae')

  # Training setting
  total_epochs = len(record_df)
  r_epochs = len(record_df)

  epoch_length = 50000
  num_epochs = 20
  iter_num = 0

  total_epochs += num_epochs

  losses = np.zeros((epoch_length, 5))
  rpn_accuracy_rpn_monitor = []
  rpn_accuracy_for_epoch = []

  if len(record_df)==0:
      best_loss = np.Inf
  else:
      best_loss = np.min(r_curr_loss)
  
  print(len(record_df))

  start_time = time.time()
  for epoch_num in range(num_epochs):

      progbar = generic_utils.Progbar(epoch_length)
      print('Epoch {}/{}'.format(r_epochs + 1, total_epochs))
      
      r_epochs += 1

      while True:
          try:

              if len(rpn_accuracy_rpn_monitor) == epoch_length and C.verbose:
                  mean_overlapping_bboxes = float(sum(rpn_accuracy_rpn_monitor))/len(rpn_accuracy_rpn_monitor)
                  rpn_accuracy_rpn_monitor = []
  #                 print('Average number of overlapping bounding boxes from RPN = {} for {} previous iterations'.format(mean_overlapping_bboxes, epoch_length))
                  if mean_overlapping_bboxes == 0:
                      print('RPN is not producing bounding boxes that overlap the ground truth boxes. Check RPN settings or keep training.')

              # Generate X (x_img) and label Y ([y_rpn_cls, y_rpn_regr])
              X, Y, img_data, debug_img, debug_num_pos = next(data_gen_train)

              # Train rpn model and get loss value [_, loss_rpn_cls, loss_rpn_regr]
              loss_rpn = model_rpn.train_on_batch(X, Y)

              # Get predicted rpn from rpn model [rpn_cls, rpn_regr]
              P_rpn = model_rpn.predict_on_batch(X)

              # R: bboxes (shape=(300,4))
              # Convert rpn layer to roi bboxes
              R = rpn_to_roi(P_rpn[0], P_rpn[1], C, K.image_dim_ordering(), use_regr=True, overlap_thresh=0.7, max_boxes=300)
              
              # note: calc_iou converts from (x1,y1,x2,y2) to (x,y,w,h) format
              # X2: bboxes that iou > C.classifier_min_overlap for all gt bboxes in 300 non_max_suppression bboxes
              # Y1: one hot code for bboxes from above => x_roi (X)
              # Y2: corresponding labels and corresponding gt bboxes
              X2, Y1, Y2, IouS = calc_iou(R, img_data, C, class_mapping)

              # If X2 is None means there are no matching bboxes
              if X2 is None:
                  rpn_accuracy_rpn_monitor.append(0)
                  rpn_accuracy_for_epoch.append(0)
                  continue
              
              # Find out the positive anchors and negative anchors
              neg_samples = np.where(Y1[0, :, -1] == 1)
              pos_samples = np.where(Y1[0, :, -1] == 0)

              if len(neg_samples) > 0:
                  neg_samples = neg_samples[0]
              else:
                  neg_samples = []

              if len(pos_samples) > 0:
                  pos_samples = pos_samples[0]
              else:
                  pos_samples = []

              rpn_accuracy_rpn_monitor.append(len(pos_samples))
              rpn_accuracy_for_epoch.append((len(pos_samples)))

              if C.num_rois > 1:
                  # If number of positive anchors is larger than 4//2 = 2, randomly choose 2 pos samples
                  if len(pos_samples) < C.num_rois//2:
                      selected_pos_samples = pos_samples.tolist()
                  else:
                      selected_pos_samples = np.random.choice(pos_samples, C.num_rois//2, replace=False).tolist()
                  
                  # Randomly choose (num_rois - num_pos) neg samples
                  try:
                      selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=False).tolist()
                  except:
                      selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=True).tolist()
                  
                  # Save all the pos and neg samples in sel_samples
                  sel_samples = selected_pos_samples + selected_neg_samples
              else:
                  # in the extreme case where num_rois = 1, we pick a random pos or neg sample
                  selected_pos_samples = pos_samples.tolist()
                  selected_neg_samples = neg_samples.tolist()
                  if np.random.randint(0, 2):
                      sel_samples = random.choice(neg_samples)
                  else:
                      sel_samples = random.choice(pos_samples)

              # training_data: [X, X2[:, sel_samples, :]]
              # labels: [Y1[:, sel_samples, :], Y2[:, sel_samples, :]]
              #  X                     => img_data resized image
              #  X2[:, sel_samples, :] => num_rois (4 in here) bboxes which contains selected neg and pos
              #  Y1[:, sel_samples, :] => one hot encode for num_rois bboxes which contains selected neg and pos
              #  Y2[:, sel_samples, :] => labels and gt bboxes for num_rois bboxes which contains selected neg and pos
              loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])

              losses[iter_num, 0] = loss_rpn[1]
              losses[iter_num, 1] = loss_rpn[2]

              losses[iter_num, 2] = loss_class[1]
              losses[iter_num, 3] = loss_class[2]
              losses[iter_num, 4] = loss_class[3]

              iter_num += 1

              progbar.update(iter_num, [('rpn_cls', np.mean(losses[:iter_num, 0])), ('rpn_regr', np.mean(losses[:iter_num, 1])),
                                        ('final_cls', np.mean(losses[:iter_num, 2])), ('final_regr', np.mean(losses[:iter_num, 3]))])

              if iter_num == epoch_length:
                  loss_rpn_cls = np.mean(losses[:, 0])
                  loss_rpn_regr = np.mean(losses[:, 1])
                  loss_class_cls = np.mean(losses[:, 2])
                  loss_class_regr = np.mean(losses[:, 3])
                  class_acc = np.mean(losses[:, 4])

                  mean_overlapping_bboxes = float(sum(rpn_accuracy_for_epoch)) / len(rpn_accuracy_for_epoch)
                  rpn_accuracy_for_epoch = []

                  if C.verbose:
                      print('Mean number of bounding boxes from RPN overlapping ground truth boxes: {}'.format(mean_overlapping_bboxes))
                      print('Classifier accuracy for bounding boxes from RPN: {}'.format(class_acc))
                      print('Loss RPN classifier: {}'.format(loss_rpn_cls))
                      print('Loss RPN regression: {}'.format(loss_rpn_regr))
                      print('Loss Detector classifier: {}'.format(loss_class_cls))
                      print('Loss Detector regression: {}'.format(loss_class_regr))
                      print('Total loss: {}'.format(loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr))
                      print('Elapsed time: {}'.format(time.time() - start_time))
                      elapsed_time = (time.time()-start_time)/60

                  curr_loss = loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr
                  iter_num = 0
                  start_time = time.time()

                  if curr_loss < best_loss:
                      if C.verbose:
                          print('Total loss decreased from {} to {}, saving weights'.format(best_loss,curr_loss))
                      best_loss = curr_loss
                      model_all.save_weights(C.model_path)

                  new_row = {'mean_overlapping_bboxes':round(mean_overlapping_bboxes, 3), 
                            'class_acc':round(class_acc, 3), 
                            'loss_rpn_cls':round(loss_rpn_cls, 3), 
                            'loss_rpn_regr':round(loss_rpn_regr, 3), 
                            'loss_class_cls':round(loss_class_cls, 3), 
                            'loss_class_regr':round(loss_class_regr, 3), 
                            'curr_loss':round(curr_loss, 3), 
                            'elapsed_time':round(elapsed_time, 3), 
                            'mAP': 0}

                  record_df = record_df.append(new_row, ignore_index=True)
                  record_df.to_csv(record_path, index=0)

                  break

          except Exception as e:
              print('Exception: {}'.format(e))
              continue

  print('Training complete, exiting.')

# %% [markdown]
# **Main Function**

# %%
def main():
  preparation()
  explore_data_gen_train()
  build_model()

# %%
main()
# Out:
# Streaming output truncated to the last 5000 lines.
# ridx=35780/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5468/spoof/035779.jpg
# ridx=35781/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7006/spoof/035780.jpg
# ridx=35782/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5579/spoof/035781.jpg
# ridx=35783/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7779/spoof/035782.jpg
# ridx=35784/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9565/live/035783.jpg
# ridx=35785/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1982/spoof/035784.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1982/spoof/035784.jpg tidak bisa ditemukan!
# ridx=35786/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1580/spoof/035785.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1580/spoof/035785.jpg tidak bisa ditemukan!
# ridx=35787/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2826/spoof/035786.jpg
# ridx=35788/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8979/spoof/035787.jpg
# ridx=35789/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10172/spoof/035788.jpg
# ridx=35790/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8160/spoof/035789.jpg
# ridx=35791/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1871/spoof/035790.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1871/spoof/035790.jpg tidak bisa ditemukan!
# ridx=35792/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/994/live/035791.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/994/live/035791.jpg tidak bisa ditemukan!
# ridx=35793/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/884/spoof/035792.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/884/spoof/035792.jpg tidak bisa ditemukan!
# ridx=35794/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/587/spoof/035793.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/587/spoof/035793.jpg tidak bisa ditemukan!
# ridx=35795/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2315/spoof/035794.jpg
# ridx=35796/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7657/spoof/035795.jpg
# ridx=35797/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/970/spoof/035796.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/970/spoof/035796.jpg tidak bisa ditemukan!
# ridx=35798/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3184/spoof/035797.jpg
# ridx=35799/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/542/live/035798.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/542/live/035798.jpg tidak bisa ditemukan!
# ridx=35800/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5561/spoof/035799.jpg
# ridx=35801/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/424/live/035800.jpg
# ridx=35802/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5484/spoof/035801.jpg
# ridx=35803/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4444/spoof/035802.jpg
# ridx=35804/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/358/live/035803.jpg
# ridx=35805/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6684/spoof/035804.jpg
# ridx=35806/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4886/live/035805.jpg
# ridx=35807/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5274/spoof/035806.jpg
# ridx=35808/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7331/spoof/035807.jpg
# ridx=35809/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2409/spoof/035808.jpg
# ridx=35810/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9689/spoof/035809.jpg
# ridx=35811/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5617/live/035810.jpg
# ridx=35812/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3993/spoof/035811.jpg
# ridx=35813/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/13/spoof/035812.jpg
# ridx=35814/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10067/spoof/035813.jpg
# ridx=35815/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/932/spoof/035814.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/932/spoof/035814.jpg tidak bisa ditemukan!
# ridx=35816/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8623/spoof/035815.jpg
# ridx=35817/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4482/spoof/035816.jpg
# ridx=35818/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3896/live/035817.jpg
# ridx=35819/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9241/spoof/035818.jpg
# ridx=35820/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9470/spoof/035819.jpg
# ridx=35821/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5093/spoof/035820.jpg
# ridx=35822/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7814/spoof/035821.jpg
# ridx=35823/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3346/live/035822.jpg
# ridx=35824/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1936/spoof/035823.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1936/spoof/035823.jpg tidak bisa ditemukan!
# ridx=35825/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6689/spoof/035824.jpg
# ridx=35826/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1723/spoof/035825.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1723/spoof/035825.jpg tidak bisa ditemukan!
# ridx=35827/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9989/spoof/035826.jpg
# ridx=35828/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8735/spoof/035827.jpg
# ridx=35829/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/302/live/035828.jpg
# ridx=35830/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/829/spoof/035829.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/829/spoof/035829.jpg tidak bisa ditemukan!
# ridx=35831/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7647/live/035830.jpg
# ridx=35832/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5053/spoof/035831.jpg
# ridx=35833/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3131/live/035832.jpg
# ridx=35834/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3067/spoof/035833.jpg
# ridx=35835/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6340/spoof/035834.jpg
# ridx=35836/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9854/live/035835.jpg
# ridx=35837/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/324/spoof/035836.jpg
# ridx=35838/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6986/live/035837.jpg
# ridx=35839/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4977/spoof/035838.jpg
# ridx=35840/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4373/live/035839.jpg
# ridx=35841/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4214/spoof/035840.jpg
# ridx=35842/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6137/live/035841.jpg
# ridx=35843/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2316/live/035842.jpg
# ridx=35844/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9303/spoof/035843.jpg
# ridx=35845/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4466/spoof/035844.jpg
# ridx=35846/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9288/spoof/035845.jpg
# ridx=35847/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8293/spoof/035846.jpg
# ridx=35848/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/821/live/035847.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/821/live/035847.jpg tidak bisa ditemukan!
# ridx=35849/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6000/spoof/035848.jpg
# ridx=35850/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/361/live/035849.jpg
# ridx=35851/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8623/spoof/035850.jpg
# ridx=35852/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6348/spoof/035851.jpg
# ridx=35853/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2832/spoof/035852.jpg
# ridx=35854/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/646/spoof/035853.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/646/spoof/035853.jpg tidak bisa ditemukan!
# ridx=35855/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2111/live/035854.jpg
# ridx=35856/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/539/spoof/035855.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/539/spoof/035855.jpg tidak bisa ditemukan!
# ridx=35857/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9921/spoof/035856.jpg
# ridx=35858/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7701/spoof/035857.jpg
# ridx=35859/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8636/live/035858.jpg
# ridx=35860/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9071/spoof/035859.jpg
# ridx=35861/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7454/live/035860.jpg
# ridx=35862/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3749/live/035861.jpg
# ridx=35863/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4051/spoof/035862.jpg
# ridx=35864/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6275/spoof/035863.jpg
# ridx=35865/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/495/spoof/035864.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/495/spoof/035864.jpg tidak bisa ditemukan!
# ridx=35866/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6840/spoof/035865.jpg
# ridx=35867/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9674/spoof/035866.jpg
# ridx=35868/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2464/live/035867.jpg
# ridx=35869/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4061/live/035868.jpg
# ridx=35870/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5138/spoof/035869.jpg
# ridx=35871/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10091/spoof/035870.jpg
# ridx=35872/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4201/live/035871.jpg
# ridx=35873/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8852/spoof/035872.jpg
# ridx=35874/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7319/spoof/035873.jpg
# ridx=35875/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3021/spoof/035874.jpg
# ridx=35876/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/123/spoof/035875.jpg
# ridx=35877/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2080/spoof/035876.jpg
# ridx=35878/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3338/spoof/035877.jpg
# ridx=35879/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10149/live/035878.jpg
# ridx=35880/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5685/live/035879.jpg
# ridx=35881/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1318/live/035880.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1318/live/035880.jpg tidak bisa ditemukan!
# ridx=35882/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6037/spoof/035881.jpg
# ridx=35883/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5440/spoof/035882.jpg
# ridx=35884/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/932/live/035883.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/932/live/035883.jpg tidak bisa ditemukan!
# ridx=35885/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4040/spoof/035884.jpg
# ridx=35886/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6815/spoof/035885.jpg
# ridx=35887/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2508/spoof/035886.jpg
# ridx=35888/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10010/spoof/035887.jpg
# ridx=35889/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3893/spoof/035888.jpg
# ridx=35890/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/925/live/035889.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/925/live/035889.jpg tidak bisa ditemukan!
# ridx=35891/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7290/spoof/035890.jpg
# ridx=35892/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3103/spoof/035891.jpg
# ridx=35893/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7992/spoof/035892.jpg
# ridx=35894/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2909/live/035893.jpg
# ridx=35895/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3895/live/035894.jpg
# ridx=35896/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3899/live/035895.jpg
# ridx=35897/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5690/live/035896.jpg
# ridx=35898/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9492/spoof/035897.jpg
# ridx=35899/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/449/spoof/035898.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/449/spoof/035898.jpg tidak bisa ditemukan!
# ridx=35900/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2057/spoof/035899.jpg
# ridx=35901/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6640/live/035900.jpg
# ridx=35902/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5369/live/035901.jpg
# ridx=35903/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6788/spoof/035902.jpg
# ridx=35904/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5998/spoof/035903.jpg
# ridx=35905/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6483/live/035904.jpg
# ridx=35906/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6722/spoof/035905.jpg
# ridx=35907/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6233/spoof/035906.jpg
# ridx=35908/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/364/spoof/035907.jpg
# ridx=35909/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/485/live/035908.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/485/live/035908.jpg tidak bisa ditemukan!
# ridx=35910/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2661/spoof/035909.jpg
# ridx=35911/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1521/spoof/035910.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1521/spoof/035910.jpg tidak bisa ditemukan!
# ridx=35912/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5915/spoof/035911.jpg
# ridx=35913/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8165/spoof/035912.jpg
# ridx=35914/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2794/spoof/035913.jpg
# ridx=35915/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2414/live/035914.jpg
# ridx=35916/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2006/spoof/035915.jpg
# ridx=35917/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3185/spoof/035916.jpg
# ridx=35918/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/847/spoof/035917.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/847/spoof/035917.jpg tidak bisa ditemukan!
# ridx=35919/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4338/live/035918.jpg
# ridx=35920/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3994/spoof/035919.jpg
# ridx=35921/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8933/live/035920.jpg
# ridx=35922/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3509/live/035921.jpg
# ridx=35923/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7300/live/035922.jpg
# ridx=35924/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/53/spoof/035923.jpg
# ridx=35925/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/744/live/035924.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/744/live/035924.jpg tidak bisa ditemukan!
# ridx=35926/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1327/spoof/035925.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1327/spoof/035925.jpg tidak bisa ditemukan!
# ridx=35927/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2088/spoof/035926.jpg
# ridx=35928/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4758/spoof/035927.jpg
# ridx=35929/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5684/spoof/035928.jpg
# ridx=35930/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2769/spoof/035929.jpg
# ridx=35931/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5482/spoof/035930.jpg
# ridx=35932/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1670/spoof/035931.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1670/spoof/035931.jpg tidak bisa ditemukan!
# ridx=35933/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4878/live/035932.jpg
# ridx=35934/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9878/live/035933.jpg
# ridx=35935/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6145/spoof/035934.jpg
# ridx=35936/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6558/spoof/035935.jpg
# ridx=35937/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5022/spoof/035936.jpg
# ridx=35938/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2690/spoof/035937.jpg
# ridx=35939/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4/live/035938.jpg
# ridx=35940/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1533/live/035939.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1533/live/035939.jpg tidak bisa ditemukan!
# ridx=35941/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3630/spoof/035940.jpg
# ridx=35942/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6346/spoof/035941.jpg
# ridx=35943/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8928/live/035942.jpg
# ridx=35944/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9293/spoof/035943.jpg
# ridx=35945/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3221/live/035944.jpg
# ridx=35946/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9676/spoof/035945.jpg
# ridx=35947/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/535/spoof/035946.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/535/spoof/035946.jpg tidak bisa ditemukan!
# ridx=35948/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7780/spoof/035947.jpg
# ridx=35949/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7369/live/035948.jpg
# ridx=35950/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9557/spoof/035949.jpg
# ridx=35951/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3869/spoof/035950.jpg
# ridx=35952/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/122/spoof/035951.jpg
# ridx=35953/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9158/spoof/035952.jpg
# ridx=35954/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3042/live/035953.jpg
# ridx=35955/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8816/live/035954.jpg
# ridx=35956/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7744/spoof/035955.jpg
# ridx=35957/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1610/spoof/035956.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1610/spoof/035956.jpg tidak bisa ditemukan!
# ridx=35958/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8551/live/035957.jpg
# ridx=35959/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2688/spoof/035958.jpg
# ridx=35960/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4066/live/035959.jpg
# ridx=35961/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5767/spoof/035960.jpg
# ridx=35962/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3259/spoof/035961.jpg
# ridx=35963/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8127/spoof/035962.jpg
# ridx=35964/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/168/spoof/035963.jpg
# ridx=35965/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2671/spoof/035964.jpg
# ridx=35966/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/889/spoof/035965.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/889/spoof/035965.jpg tidak bisa ditemukan!
# ridx=35967/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9892/spoof/035966.jpg
# ridx=35968/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5310/spoof/035967.jpg
# ridx=35969/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9208/spoof/035968.jpg
# ridx=35970/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3147/live/035969.jpg
# ridx=35971/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7479/spoof/035970.jpg
# ridx=35972/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2105/live/035971.jpg
# ridx=35973/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9786/spoof/035972.jpg
# ridx=35974/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3096/spoof/035973.jpg
# ridx=35975/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9168/spoof/035974.jpg
# ridx=35976/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8908/live/035975.jpg
# ridx=35977/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4351/spoof/035976.jpg
# ridx=35978/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2784/spoof/035977.jpg
# ridx=35979/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7153/spoof/035978.jpg
# ridx=35980/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/843/spoof/035979.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/843/spoof/035979.jpg tidak bisa ditemukan!
# ridx=35981/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7387/spoof/035980.jpg
# ridx=35982/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8276/spoof/035981.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8276/spoof/035981.jpg tidak bisa ditemukan!
# ridx=35983/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8837/spoof/035982.jpg
# ridx=35984/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5748/live/035983.jpg
# ridx=35985/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5358/live/035984.jpg
# ridx=35986/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8555/spoof/035985.jpg
# ridx=35987/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2370/live/035986.jpg
# ridx=35988/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10030/spoof/035987.jpg
# ridx=35989/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3558/live/035988.jpg
# ridx=35990/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9834/spoof/035989.jpg
# ridx=35991/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/815/spoof/035990.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/815/spoof/035990.jpg tidak bisa ditemukan!
# ridx=35992/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/438/spoof/035991.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/438/spoof/035991.jpg tidak bisa ditemukan!
# ridx=35993/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1400/spoof/035992.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1400/spoof/035992.jpg tidak bisa ditemukan!
# ridx=35994/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4814/spoof/035993.jpg
# ridx=35995/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/985/spoof/035994.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/985/spoof/035994.jpg tidak bisa ditemukan!
# ridx=35996/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/463/spoof/035995.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/463/spoof/035995.jpg tidak bisa ditemukan!
# ridx=35997/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9537/spoof/035996.jpg
# ridx=35998/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9320/live/035997.jpg
# ridx=35999/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/244/spoof/035998.jpg
# ridx=36000/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9598/spoof/035999.jpg
# ridx=36001/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8743/spoof/036000.jpg
# ridx=36002/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2614/spoof/036001.jpg
# ridx=36003/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4692/live/036002.jpg
# ridx=36004/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3473/spoof/036003.jpg
# ridx=36005/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9628/spoof/036004.jpg
# ridx=36006/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2337/spoof/036005.jpg
# ridx=36007/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5086/spoof/036006.jpg
# ridx=36008/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6640/spoof/036007.jpg
# ridx=36009/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8685/live/036008.jpg
# ridx=36010/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7014/spoof/036009.jpg
# ridx=36011/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9484/spoof/036010.jpg
# ridx=36012/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7384/spoof/036011.jpg
# ridx=36013/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1761/spoof/036012.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1761/spoof/036012.jpg tidak bisa ditemukan!
# ridx=36014/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4062/spoof/036013.jpg
# ridx=36015/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4215/spoof/036014.jpg
# ridx=36016/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1172/live/036015.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1172/live/036015.jpg tidak bisa ditemukan!
# ridx=36017/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/418/spoof/036016.jpg
# ridx=36018/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7304/spoof/036017.jpg
# ridx=36019/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9655/live/036018.jpg
# ridx=36020/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7583/spoof/036019.jpg
# ridx=36021/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6514/spoof/036020.jpg
# ridx=36022/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/429/spoof/036021.jpg
# ridx=36023/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2262/spoof/036022.jpg
# ridx=36024/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6652/live/036023.jpg
# ridx=36025/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4216/live/036024.jpg
# ridx=36026/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9539/live/036025.jpg
# ridx=36027/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5808/spoof/036026.jpg
# ridx=36028/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9529/live/036027.jpg
# ridx=36029/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3719/spoof/036028.jpg
# ridx=36030/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/374/spoof/036029.jpg
# ridx=36031/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4613/spoof/036030.jpg
# ridx=36032/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2662/spoof/036031.jpg
# ridx=36033/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3966/live/036032.jpg
# ridx=36034/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2747/spoof/036033.jpg
# ridx=36035/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/951/spoof/036034.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/951/spoof/036034.jpg tidak bisa ditemukan!
# ridx=36036/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9630/spoof/036035.jpg
# ridx=36037/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3473/spoof/036036.jpg
# ridx=36038/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1986/spoof/036037.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1986/spoof/036037.jpg tidak bisa ditemukan!
# ridx=36039/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5747/spoof/036038.jpg
# ridx=36040/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2680/spoof/036039.jpg
# ridx=36041/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2425/live/036040.jpg
# ridx=36042/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5461/live/036041.jpg
# ridx=36043/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3535/spoof/036042.jpg
# ridx=36044/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1477/spoof/036043.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1477/spoof/036043.jpg tidak bisa ditemukan!
# ridx=36045/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9725/live/036044.jpg
# ridx=36046/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5959/spoof/036045.jpg
# ridx=36047/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3753/spoof/036046.jpg
# ridx=36048/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1546/spoof/036047.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1546/spoof/036047.jpg tidak bisa ditemukan!
# ridx=36049/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9285/spoof/036048.jpg
# ridx=36050/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5409/spoof/036049.jpg
# ridx=36051/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1814/spoof/036050.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1814/spoof/036050.jpg tidak bisa ditemukan!
# ridx=36052/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/138/live/036051.jpg
# ridx=36053/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5436/spoof/036052.jpg
# ridx=36054/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/874/spoof/036053.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/874/spoof/036053.jpg tidak bisa ditemukan!
# ridx=36055/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3286/spoof/036054.jpg
# ridx=36056/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6556/spoof/036055.jpg
# ridx=36057/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2208/spoof/036056.jpg
# ridx=36058/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2202/spoof/036057.jpg
# ridx=36059/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2481/spoof/036058.jpg
# ridx=36060/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2317/spoof/036059.jpg
# ridx=36061/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6467/live/036060.jpg
# ridx=36062/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4994/spoof/036061.jpg
# ridx=36063/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3590/spoof/036062.jpg
# ridx=36064/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6083/live/036063.jpg
# ridx=36065/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3396/spoof/036064.jpg
# ridx=36066/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5699/live/036065.jpg
# ridx=36067/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8209/spoof/036066.jpg
# ridx=36068/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/244/spoof/036067.jpg
# ridx=36069/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/416/spoof/036068.jpg
# ridx=36070/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7560/live/036069.jpg
# ridx=36071/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5499/live/036070.jpg
# ridx=36072/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10044/live/036071.jpg
# ridx=36073/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7387/spoof/036072.jpg
# ridx=36074/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6457/spoof/036073.jpg
# ridx=36075/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/492/spoof/036074.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/492/spoof/036074.jpg tidak bisa ditemukan!
# ridx=36076/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4026/spoof/036075.jpg
# ridx=36077/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7635/spoof/036076.jpg
# ridx=36078/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3353/spoof/036077.jpg
# ridx=36079/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3331/live/036078.jpg
# ridx=36080/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1112/live/036079.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1112/live/036079.jpg tidak bisa ditemukan!
# ridx=36081/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4731/spoof/036080.jpg
# ridx=36082/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1602/live/036081.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1602/live/036081.jpg tidak bisa ditemukan!
# ridx=36083/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/117/live/036082.jpg
# ridx=36084/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3454/spoof/036083.jpg
# ridx=36085/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7634/live/036084.jpg
# ridx=36086/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7511/spoof/036085.jpg
# ridx=36087/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9450/spoof/036086.jpg
# ridx=36088/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8784/spoof/036087.jpg
# ridx=36089/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6006/spoof/036088.jpg
# ridx=36090/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5459/spoof/036089.jpg
# ridx=36091/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8012/spoof/036090.jpg
# ridx=36092/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3993/spoof/036091.jpg
# ridx=36093/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1825/live/036092.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1825/live/036092.jpg tidak bisa ditemukan!
# ridx=36094/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6034/spoof/036093.jpg
# ridx=36095/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/655/live/036094.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/655/live/036094.jpg tidak bisa ditemukan!
# ridx=36096/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7636/live/036095.jpg
# ridx=36097/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4719/live/036096.jpg
# ridx=36098/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1814/live/036097.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1814/live/036097.jpg tidak bisa ditemukan!
# ridx=36099/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7767/spoof/036098.jpg
# ridx=36100/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5378/spoof/036099.jpg
# ridx=36101/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3985/live/036100.jpg
# ridx=36102/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5700/spoof/036101.jpg
# ridx=36103/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4374/live/036102.jpg
# ridx=36104/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3084/live/036103.jpg
# ridx=36105/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8203/spoof/036104.jpg
# ridx=36106/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5641/spoof/036105.jpg
# ridx=36107/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5372/live/036106.jpg
# ridx=36108/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7843/spoof/036107.jpg
# ridx=36109/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9204/spoof/036108.jpg
# ridx=36110/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2980/spoof/036109.jpg
# ridx=36111/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1940/live/036110.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1940/live/036110.jpg tidak bisa ditemukan!
# ridx=36112/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1823/live/036111.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1823/live/036111.jpg tidak bisa ditemukan!
# ridx=36113/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8551/spoof/036112.jpg
# ridx=36114/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8599/live/036113.jpg
# ridx=36115/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8983/spoof/036114.jpg
# ridx=36116/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10016/spoof/036115.jpg
# ridx=36117/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9440/spoof/036116.jpg
# ridx=36118/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1165/live/036117.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1165/live/036117.jpg tidak bisa ditemukan!
# ridx=36119/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6995/spoof/036118.jpg
# ridx=36120/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3787/spoof/036119.jpg
# ridx=36121/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6993/spoof/036120.jpg
# ridx=36122/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9190/spoof/036121.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9190/spoof/036121.jpg tidak bisa ditemukan!
# ridx=36123/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5251/spoof/036122.jpg
# ridx=36124/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9547/spoof/036123.jpg
# ridx=36125/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7858/live/036124.jpg
# ridx=36126/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5116/spoof/036125.jpg
# ridx=36127/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9473/live/036126.jpg
# ridx=36128/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9571/spoof/036127.jpg
# ridx=36129/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9410/spoof/036128.jpg
# ridx=36130/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4939/spoof/036129.jpg
# ridx=36131/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3402/live/036130.jpg
# ridx=36132/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6772/spoof/036131.jpg
# ridx=36133/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3892/spoof/036132.jpg
# ridx=36134/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5806/live/036133.jpg
# ridx=36135/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1237/live/036134.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1237/live/036134.jpg tidak bisa ditemukan!
# ridx=36136/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/316/spoof/036135.jpg
# ridx=36137/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1874/spoof/036136.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1874/spoof/036136.jpg tidak bisa ditemukan!
# ridx=36138/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/501/spoof/036137.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/501/spoof/036137.jpg tidak bisa ditemukan!
# ridx=36139/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2038/spoof/036138.jpg
# ridx=36140/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8610/spoof/036139.jpg
# ridx=36141/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2419/spoof/036140.jpg
# ridx=36142/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2806/live/036141.jpg
# ridx=36143/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8519/spoof/036142.jpg
# ridx=36144/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3333/live/036143.jpg
# ridx=36145/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6736/spoof/036144.jpg
# ridx=36146/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6952/live/036145.jpg
# ridx=36147/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7773/spoof/036146.jpg
# ridx=36148/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2399/spoof/036147.jpg
# ridx=36149/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5054/spoof/036148.jpg
# ridx=36150/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3162/spoof/036149.jpg
# ridx=36151/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4117/live/036150.jpg
# ridx=36152/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1160/live/036151.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1160/live/036151.jpg tidak bisa ditemukan!
# ridx=36153/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2980/live/036152.jpg
# ridx=36154/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7733/live/036153.jpg
# ridx=36155/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6465/live/036154.jpg
# ridx=36156/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/562/spoof/036155.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/562/spoof/036155.jpg tidak bisa ditemukan!
# ridx=36157/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9089/spoof/036156.jpg
# ridx=36158/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/433/live/036157.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/433/live/036157.jpg tidak bisa ditemukan!
# ridx=36159/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9013/live/036158.jpg
# ridx=36160/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7704/spoof/036159.jpg
# ridx=36161/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1301/spoof/036160.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1301/spoof/036160.jpg tidak bisa ditemukan!
# ridx=36162/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5188/live/036161.jpg
# ridx=36163/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10000/spoof/036162.jpg
# ridx=36164/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9186/spoof/036163.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9186/spoof/036163.jpg tidak bisa ditemukan!
# ridx=36165/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/132/spoof/036164.jpg
# ridx=36166/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7243/spoof/036165.jpg
# ridx=36167/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2902/spoof/036166.jpg
# ridx=36168/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8654/live/036167.jpg
# ridx=36169/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7916/spoof/036168.jpg
# ridx=36170/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8096/spoof/036169.jpg
# ridx=36171/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3497/spoof/036170.jpg
# ridx=36172/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4126/spoof/036171.jpg
# ridx=36173/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3982/live/036172.jpg
# ridx=36174/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9198/spoof/036173.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9198/spoof/036173.jpg tidak bisa ditemukan!
# ridx=36175/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6260/spoof/036174.jpg
# ridx=36176/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3911/spoof/036175.jpg
# ridx=36177/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8120/live/036176.jpg
# ridx=36178/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5775/spoof/036177.jpg
# ridx=36179/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4046/spoof/036178.jpg
# ridx=36180/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4211/spoof/036179.jpg
# ridx=36181/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4449/spoof/036180.jpg
# ridx=36182/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1152/spoof/036181.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1152/spoof/036181.jpg tidak bisa ditemukan!
# ridx=36183/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8354/live/036182.jpg
# ridx=36184/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3398/spoof/036183.jpg
# ridx=36185/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5361/live/036184.jpg
# ridx=36186/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6493/spoof/036185.jpg
# ridx=36187/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/20/spoof/036186.jpg
# ridx=36188/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5660/spoof/036187.jpg
# ridx=36189/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9568/spoof/036188.jpg
# ridx=36190/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7026/live/036189.jpg
# ridx=36191/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9685/spoof/036190.jpg
# ridx=36192/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4298/live/036191.jpg
# ridx=36193/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6159/spoof/036192.jpg
# ridx=36194/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9730/spoof/036193.jpg
# ridx=36195/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/834/live/036194.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/834/live/036194.jpg tidak bisa ditemukan!
# ridx=36196/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1736/live/036195.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1736/live/036195.jpg tidak bisa ditemukan!
# ridx=36197/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8331/spoof/036196.jpg
# ridx=36198/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6262/live/036197.jpg
# ridx=36199/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8523/live/036198.jpg
# ridx=36200/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6422/spoof/036199.jpg
# ridx=36201/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2330/live/036200.jpg
# ridx=36202/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/91/spoof/036201.jpg
# ridx=36203/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8160/spoof/036202.jpg
# ridx=36204/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7819/live/036203.jpg
# ridx=36205/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3756/spoof/036204.jpg
# ridx=36206/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1453/spoof/036205.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1453/spoof/036205.jpg tidak bisa ditemukan!
# ridx=36207/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2328/spoof/036206.jpg
# ridx=36208/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2798/spoof/036207.jpg
# ridx=36209/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5345/spoof/036208.jpg
# ridx=36210/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2486/live/036209.jpg
# ridx=36211/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6585/live/036210.jpg
# ridx=36212/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8160/spoof/036211.jpg
# ridx=36213/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7528/spoof/036212.jpg
# ridx=36214/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5538/spoof/036213.jpg
# ridx=36215/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2549/spoof/036214.jpg
# ridx=36216/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5038/spoof/036215.jpg
# ridx=36217/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5450/spoof/036216.jpg
# ridx=36218/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2561/spoof/036217.jpg
# ridx=36219/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/467/spoof/036218.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/467/spoof/036218.jpg tidak bisa ditemukan!
# ridx=36220/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/447/spoof/036219.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/447/spoof/036219.jpg tidak bisa ditemukan!
# ridx=36221/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4051/spoof/036220.jpg
# ridx=36222/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9165/spoof/036221.jpg
# ridx=36223/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8070/live/036222.jpg
# ridx=36224/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1303/live/036223.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1303/live/036223.jpg tidak bisa ditemukan!
# ridx=36225/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6368/spoof/036224.jpg
# ridx=36226/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2770/live/036225.jpg
# ridx=36227/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4927/spoof/036226.jpg
# ridx=36228/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4040/spoof/036227.jpg
# ridx=36229/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1612/spoof/036228.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1612/spoof/036228.jpg tidak bisa ditemukan!
# ridx=36230/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8740/spoof/036229.jpg
# ridx=36231/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3073/spoof/036230.jpg
# ridx=36232/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3121/live/036231.jpg
# ridx=36233/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3156/spoof/036232.jpg
# ridx=36234/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3080/live/036233.jpg
# ridx=36235/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4501/spoof/036234.jpg
# ridx=36236/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2363/spoof/036235.jpg
# ridx=36237/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9293/spoof/036236.jpg
# ridx=36238/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7737/spoof/036237.jpg
# ridx=36239/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4837/spoof/036238.jpg
# ridx=36240/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7196/spoof/036239.jpg
# ...
# ridx=39915/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7800/spoof/039914.jpg
# ridx=39916/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5608/spoof/039915.jpg
# ridx=39917/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1173/live/039916.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1173/live/039916.jpg tidak bisa ditemukan!
# ridx=39918/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9642/spoof/039917.jpg
# ridx=39919/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1005/live/039918.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1005/live/039918.jpg tidak bisa ditemukan!
# ridx=39920/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4976/spoof/039919.jpg
# ridx=39921/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/934/spoof/039920.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/934/spoof/039920.jpg tidak bisa ditemukan!
# ridx=39922/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2947/live/039921.jpg
# ridx=39923/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8921/spoof/039922.jpg
# ridx=39924/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/179/spoof/039923.jpg
# ridx=39925/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9483/spoof/039924.jpg
# ridx=39926/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4950/spoof/039925.jpg
# ridx=39927/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4330/spoof/039926.jpg
# ridx=39928/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9998/spoof/039927.jpg
# ridx=39929/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2575/spoof/039928.jpg
# ridx=39930/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1756/live/039929.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1756/live/039929.jpg tidak bisa ditemukan!
# ridx=39931/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5763/spoof/039930.jpg
# ridx=39932/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2975/live/039931.jpg
# ridx=39933/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8818/spoof/039932.jpg
# ridx=39934/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7123/spoof/039933.jpg
# ridx=39935/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3050/spoof/039934.jpg
# ridx=39936/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2705/spoof/039935.jpg
# ridx=39937/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10055/spoof/039936.jpg
# ridx=39938/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/728/spoof/039937.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/728/spoof/039937.jpg tidak bisa ditemukan!
# ridx=39939/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/497/live/039938.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/497/live/039938.jpg tidak bisa ditemukan!
# ridx=39940/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/382/spoof/039939.jpg
# ridx=39941/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7260/spoof/039940.jpg
# ridx=39942/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5961/live/039941.jpg
# ridx=39943/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3406/spoof/039942.jpg
# ridx=39944/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5836/live/039943.jpg
# ridx=39945/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2521/spoof/039944.jpg
# ridx=39946/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/494/spoof/039945.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/494/spoof/039945.jpg tidak bisa ditemukan!
# ridx=39947/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2699/spoof/039946.jpg
# ridx=39948/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5626/spoof/039947.jpg
# ridx=39949/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8500/spoof/039948.jpg
# ridx=39950/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3723/spoof/039949.jpg
# ridx=39951/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3272/spoof/039950.jpg
# ridx=39952/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6446/live/039951.jpg
# ridx=39953/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9872/spoof/039952.jpg
# ridx=39954/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/122/spoof/039953.jpg
# ridx=39955/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8106/spoof/039954.jpg
# ridx=39956/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5008/spoof/039955.jpg
# ridx=39957/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9103/spoof/039956.jpg
# ridx=39958/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10072/live/039957.jpg
# ridx=39959/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/866/spoof/039958.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/866/spoof/039958.jpg tidak bisa ditemukan!
# ridx=39960/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6928/spoof/039959.jpg
# ridx=39961/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1632/live/039960.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1632/live/039960.jpg tidak bisa ditemukan!
# ridx=39962/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1103/live/039961.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1103/live/039961.jpg tidak bisa ditemukan!
# ridx=39963/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4969/spoof/039962.jpg
# ridx=39964/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2391/live/039963.jpg
# ridx=39965/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3107/spoof/039964.jpg
# ridx=39966/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7044/spoof/039965.jpg
# ridx=39967/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6442/spoof/039966.jpg
# ridx=39968/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5867/spoof/039967.jpg
# ridx=39969/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5637/live/039968.jpg
# ridx=39970/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4134/spoof/039969.jpg
# ridx=39971/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4980/spoof/039970.jpg
# ridx=39972/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4593/live/039971.jpg
# ridx=39973/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9459/spoof/039972.jpg
# ridx=39974/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7066/live/039973.jpg
# ridx=39975/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9158/live/039974.jpg
# ridx=39976/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/10123/spoof/039975.jpg
# ridx=39977/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7554/spoof/039976.jpg
# ridx=39978/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5764/spoof/039977.jpg
# ridx=39979/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6214/live/039978.jpg
# ridx=39980/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7911/spoof/039979.jpg
# ridx=39981/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2401/spoof/039980.jpg
# ridx=39982/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2033/spoof/039981.jpg
# ridx=39983/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8781/spoof/039982.jpg
# ridx=39984/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8334/spoof/039983.jpg
# ridx=39985/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7957/live/039984.jpg
# ridx=39986/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8456/spoof/039985.jpg
# ridx=39987/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8470/live/039986.jpg
# ridx=39988/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3979/live/039987.jpg
# ridx=39989/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9368/spoof/039988.jpg
# ridx=39990/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4179/spoof/039989.jpg
# ridx=39991/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4403/spoof/039990.jpg
# ridx=39992/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/523/spoof/039991.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/523/spoof/039991.jpg tidak bisa ditemukan!
# ridx=39993/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4859/spoof/039992.jpg
# ridx=39994/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/267/spoof/039993.jpg
# ridx=39995/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2139/spoof/039994.jpg
# ridx=39996/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5190/spoof/039995.jpg
# ridx=39997/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1988/spoof/039996.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1988/spoof/039996.jpg tidak bisa ditemukan!
# ridx=39998/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/21/live/039997.jpg
# ridx=39999/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/667/spoof/039998.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/667/spoof/039998.jpg tidak bisa ditemukan!
# ridx=40000/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/252/live/039999.jpg
# ridx=40001/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4889/live/040000.jpg
# ridx=40002/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7083/spoof/040001.jpg
# ridx=40003/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/733/live/040002.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/733/live/040002.jpg tidak bisa ditemukan!
# ridx=40004/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7551/spoof/040003.jpg
# ridx=40005/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7642/spoof/040004.jpg
# ridx=40006/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1975/live/040005.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1975/live/040005.jpg tidak bisa ditemukan!
# ridx=40007/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5973/spoof/040006.jpg
# ridx=40008/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1787/spoof/040007.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1787/spoof/040007.jpg tidak bisa ditemukan!
# ridx=40009/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9949/spoof/040008.jpg
# ridx=40010/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7878/spoof/040009.jpg
# ridx=40011/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4965/spoof/040010.jpg
# ridx=40012/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/247/live/040011.jpg
# ridx=40013/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8123/live/040012.jpg
# ridx=40014/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6396/spoof/040013.jpg
# ridx=40015/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/674/live/040014.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/674/live/040014.jpg tidak bisa ditemukan!
# ridx=40016/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6321/spoof/040015.jpg
# ridx=40017/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5717/live/040016.jpg
# ridx=40018/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/137/spoof/040017.jpg
# ridx=40019/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/489/spoof/040018.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/489/spoof/040018.jpg tidak bisa ditemukan!
# ridx=40020/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5145/live/040019.jpg
# ridx=40021/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6420/live/040020.jpg
# ridx=40022/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8677/spoof/040021.jpg
# ridx=40023/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4938/spoof/040022.jpg
# ridx=40024/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9570/spoof/040023.jpg
# ridx=40025/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/436/live/040024.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/436/live/040024.jpg tidak bisa ditemukan!
# ridx=40026/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8944/spoof/040025.jpg
# ridx=40027/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/815/spoof/040026.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/815/spoof/040026.jpg tidak bisa ditemukan!
# ridx=40028/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6500/spoof/040027.jpg
# ridx=40029/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6007/live/040028.jpg
# ridx=40030/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3428/spoof/040029.jpg
# ridx=40031/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4373/spoof/040030.jpg
# ridx=40032/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1856/spoof/040031.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/1856/spoof/040031.jpg tidak bisa ditemukan!
# ridx=40033/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4853/live/040032.jpg
# ridx=40034/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6730/spoof/040033.jpg
# ridx=40035/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/503/live/040034.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/503/live/040034.jpg tidak bisa ditemukan!
# ridx=40036/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/521/live/040035.jpg
# file /content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/521/live/040035.jpg tidak bisa ditemukan!
# ridx=40037/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6928/live/040036.jpg
# ridx=40038/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2445/spoof/040037.jpg
# ridx=40039/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9529/live/040038.jpg
# ridx=40040/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5850/spoof/040039.jpg
# ridx=40041/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2008/spoof/040040.jpg
# ridx=40042/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4245/live/040041.jpg
# ridx=40043/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9267/live/040042.jpg
# ridx=40044/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5317/live/040043.jpg
# ridx=40045/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8372/spoof/040044.jpg
# ridx=40046/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8636/live/040045.jpg
# ridx=40047/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9501/live/040046.jpg
# ridx=40048/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2994/spoof/040047.jpg
# ridx=40049/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2558/live/040048.jpg
# ridx=40050/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9135/live/040049.jpg
# ridx=40051/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3526/spoof/040050.jpg
# ridx=40052/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/6218/live/040051.jpg
# ridx=40053/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/328/spoof/040052.jpg
# ridx=40054/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2222/spoof/040053.jpg
# ridx=40055/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/2832/spoof/040054.jpg
# ridx=40056/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4026/spoof/040055.jpg
# ridx=40057/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7138/spoof/040056.jpg
# ridx=40058/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5866/spoof/040057.jpg
# ridx=40059/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9020/spoof/040058.jpg
# ridx=40060/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9998/spoof/040059.jpg
# ridx=40061/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7097/spoof/040060.jpg
# ridx=40062/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/4056/live/040061.jpg
# ridx=40063/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7610/live/040062.jpg
# ridx=40064/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/7857/live/040063.jpg
# ridx=40065/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/3774/spoof/040064.jpg
# ridx=40066/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/5787/live/040065.jpg
# ridx=40067/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/9241/spoof/040066.jpg
# ridx=40068/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/408/live/040067.jpg
# ridx=40069/content/drive/MyDrive/Semester 6/TA/DATASET/Data/train/8166/spoof/040068.jpg

# %%
get_data('/content/drive/MyDrive/Semester 6/TA/DATASET/metas/intra_test/train_dummy.txt')
